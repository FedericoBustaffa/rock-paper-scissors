# %% [markdown]
# # Genetic Rock Paper Scissors
#
# The original paper on which this work is based, shows how in a _three-way_
# prey-predator model, the unexpected emerging behavior is a sort of *survival of
# the weakest*.
#
# In this setup three different species hunt each other in a cyclic way, making
# the model go towards a particular type of dynamic equilibrium. A specie
# population density oscillates continuously, since hunting means reducing the
# population of the predator of your predator.
#
# ![Ideal Orbits](images/ideal_orbits.png)
#
# The result is that the trajectory describing

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
